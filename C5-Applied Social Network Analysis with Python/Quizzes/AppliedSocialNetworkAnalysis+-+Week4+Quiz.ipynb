# %% [markdown]
# ## Applied Social Network Analysis in Python - Week 4 Quiz

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
sixten = nx.Graph()
sixten.add_edges_from([('C', 'G'), ('C', 'A'), ('G', 'D'), ('A', 'D'), ('A', 'E'), ('D', 'E'), ('D', 'B'), ('E', 'H'), ('D', 'H'), ('F', 'H')])
nx.draw_networkx(G)
two = nx.DiGraph()
two.add_edges_from([('A', 'B'), ('B', 'A'), ('A', 'C'), ('C', 'A'), ('A', 'D'), ('D', 'E'), ('E', 'C'), ('B', 'C')])
nx.draw_networkx(two)
one= nx.DiGraph()
one.add_edges_from([('A', 'B'), ('A', 'C'), ('A', 'F'), ('B', 'C'), ('B', 'D'), ('B', 'E'), ('C', 'F'), ('C', 'E'), ('D', 'E'), ('E', 'F')])
nx.draw_networkx(one)
one.degree()
two.in_degree=two.in_degree()
two.in_degree
#x1 = list(nx.jaccard_coefficient(sixten))
#print(x1)
#x2 = list(nx.resource_allocation_index(sixten))
#print(x2)
#x3 = list(nx.preferential_attachment(sixten))
#print(x3)
sixten.node['A']['community']=0
sixten.node['B']['community']=0
sixten.node['C']['community']=0
sixten.node['D']['community']=0
sixten.node['G']['community']=0
sixten.node['E']['community']=1
sixten.node['F']['community']=1
sixten.node['H']['community']=1
# Out:
# <img src="data:image/png;base64,..." width="640">
# [('G', 'F', 0), ('G', 'E', 1), ('G', 'H', 1), ('G', 'A', 4), ('G', 'B', 2), ('C', 'F', 0), ('C', 'E', 1), ('C', 'H', 0), ('C', 'D', 4), ('C', 'B', 0), ('F', 'E', 2), ('F', 'D', 1), ('F', 'A', 0), ('F', 'B', 0), ('E', 'B', 1), ('H', 'A', 2), ('H', 'B', 1), ('A', 'B', 2)]
# [('G', 'F', 0), ('G', 'E', 0), ('G', 'H', 0), ('G', 'A', 0.7), ('G', 'B', 0.2), ('C', 'F', 0), ('C', 'E', 0), ('C', 'H', 0), ('C', 'D', 0.8333333333333333), ('C', 'B', 0), ('F', 'E', 0.3333333333333333), ('F', 'D', 0), ('F', 'A', 0), ('F', 'B', 0), ('E', 'B', 0), ('H', 'A', 0), ('H', 'B', 0), ('A', 'B', 0.2)]

# %%
x4 = list(nx.cn_soundarajan_hopcroft(sixten))
print(x4)
# Out:
# [('G', 'F', 0), ('G', 'E', 1), ('G', 'H', 1), ('G', 'A', 4), ('G', 'B', 2), ('C', 'F', 0), ('C', 'E', 1), ('C', 'H', 0), ('C', 'D', 4), ('C', 'B', 0), ('F', 'E', 2), ('F', 'D', 1), ('F', 'A', 0), ('F', 'B', 0), ('E', 'B', 1), ('H', 'A', 2), ('H', 'B', 1), ('A', 'B', 2)]

# %%
x5 = list(nx.ra_index_soundarajan_hopcroft(sixten))
print(x5)
# Out:
# [('G', 'F', 0), ('G', 'E', 0), ('G', 'H', 0), ('G', 'A', 0.7), ('G', 'B', 0.2), ('C', 'F', 0), ('C', 'E', 0), ('C', 'H', 0), ('C', 'D', 0.8333333333333333), ('C', 'B', 0), ('F', 'E', 0.3333333333333333), ('F', 'D', 0), ('F', 'A', 0), ('F', 'B', 0), ('E', 'B', 0), ('H', 'A', 0), ('H', 'B', 0), ('A', 'B', 0.2)]

# %%
import operator
x5 = [(e[0], e[1], len(list(nx.common_neighbors(sixten, e[0],
e[1])))) for e in nx.non_edges(sixten)]
sorted(x5,key=operator.itemgetter(2), reverse = True)
print(x5)
# Out:
# [('G', 'F', 0), ('G', 'E', 1), ('G', 'H', 1), ('G', 'A', 2), ('G', 'B', 1), ('C', 'F', 0), ('C', 'E', 1), ('C', 'H', 0), ('C', 'D', 2), ('C', 'B', 0), ('F', 'E', 1), ('F', 'D', 1), ('F', 'A', 0), ('F', 'B', 0), ('E', 'B', 1), ('H', 'A', 2), ('H', 'B', 1), ('A', 'B', 1)]
