# %% [markdown]
# ## Applied Social Network Analysis in Python - Week 3 Quiz

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'D'), ('C', 'E'), ('E', 'D'), ('D', 'G'), ('E', 'G'), ('G', 'F')])
nx.draw_networkx(G)

degcentD = nx.degree_centrality(G)
degcentD['D']
closecentG = nx.closeness_centrality(G)
closecentG['G']
bwcentG = nx.betweenness_centrality(G, normalized=True, endpoints=False)
bwcentG['G']
bwcentedge = nx.edge_betweenness_centrality(G, normalized=False)
bwcentedge
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.3333333333333333

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
Q7 = nx.DiGraph()
Q7.add_edges_from([('A', 'B'), ('B', 'A'), ('A', 'C'), ('C','D'), ('D', 'C')])
nx.draw_networkx(Q7)
nx.pagerank(Q7,alpha=0.9)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'A': 0.07983327489935103,
#  'B': 0.06092586099927893,
#  'C': 0.4390741390007211,
#  'D': 0.420166725100649}
