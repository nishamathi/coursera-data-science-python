# %% [markdown]
# ## Applied Social Network Analysis in Python - Week 2 Quiz

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'D'), ('C', 'E'), ('E', 'D'), ('D', 'G'), ('E', 'G'), ('G', 'F')])
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.radius(G)
nx.diameter(G)
nx.nodes(G)
G.remove_node('G')
nx.is_connected(G)
T = nx.bfs_tree(G, 'A')
nx.draw_networkx(T)
nx.shortest_path_length(T,'A')
nx.center(G)
nx.periphery(G)
nx.eccentricity(G)
# Out:
# False

# %%
# %matplotlib notebook
import networkx as nx
import matplotlib.pyplot as plt
H = nx.Graph()
H.add_edges_from([('I', 'J'), ('I', 'K')])
nx.draw_networkx(I)
nx.number_connected_components(I)
I = nx.Graph()
I.add_edges_from([('A', 'C'), ('A', 'D'), ('C', 'G'), ('D', 'E'), ('D', 'H'), ('E', 'H'), ('D', 'B'), ('B', 'F'), ('F', 'H')])
nx.is_connected(I)
nx.number_connected_components(I)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 1

# %%
# %matplotlib notebook
import networkx as nx
import matplotlib.pyplot as plt
A1 = nx.DiGraph()
A1.add_edges_from([('A', 'C'), ('A', 'B'), ('B', 'C'), ('C', 'B'), ('D', 'C'), ('E', 'B'), ('C','D')])
nx.draw_networkx(A1)
B1 = nx.DiGraph()
B1.add_edges_from([('A', 'D'), ('D', 'E'), ('E', 'C'), ('B', 'C'), ('A', 'B'), ('B', 'A'), ('A', 'C'), ('C', 'A')])
nx.draw_networkx(B1)
C1 = nx.DiGraph()
C1.add_edges_from([('A', 'C'), ('B', 'A'), ('C', 'B'), ('A', 'D'), ('D', 'B')])
nx.draw_networkx(C1)
nx.is_weakly_connected(A1)
[c for c in nx.strongly_connected_components(B1)]
nx.is_strongly_connected(C1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# True

# %%
# %matplotlib notebook
import networkx as nx
import matplotlib.pyplot as plt
D1 = nx.Graph()
D1.add_edges_from([('A', 'B'), ('A', 'F'), ('A', 'C'), ('B', 'C'), ('B', 'E'), ('B', 'D'), ('C','F'), ('C','E'), ('D','E'), ('E','F'), ('E','G'), ('E','H'), ('H','G'), ('H','M'), ('H','N'), ('G','K'), ('G','M'), ('M','K'), ('K','N')])
nx.draw_networkx(D1)
nx.node_connectivity(D1)
nx.edge_connectivity(D1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 2

# %%
# %matplotlib notebook
import networkx as nx
import matplotlib.pyplot as plt
Z1 = nx.DiGraph()
Z1.add_edges_from([('A', 'C'), ('B', 'A'), ('C', 'B'), ('C', 'E'), ('D', 'A'), ('D', 'B'), ('E','H'), ('E','F'), ('F','H'), ('F','K'), ('F','G'), ('G','K'), ('H','K'), ('H','J'), ('J','E'), ('K','J')])
nx.draw_networkx(Z1)
paths = nx.all_simple_paths(Z1, 'D','K')
for path in paths:
print(path)
nx.minimum_node_cut(Z1,'E','K')
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'F', 'H'}
